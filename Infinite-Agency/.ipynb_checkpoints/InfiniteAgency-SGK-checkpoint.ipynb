# %%
import os, sys
import glob
import pandas as pd
import numpy as np
import scipy.special
import operator

from collections import Counter

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

from bokeh.charts import Histogram, defaults, vplot, hplot, show, output_file

# %%
font = {'family' : 'monospace',
        'weight' : 'medium',
        'size'   : 18}

matplotlib.rc('font', **font)

# %% [markdown]
# # Cleaning Functions

# %%
import glob
def make_big_frame():
    """
    big_frame is every .csv file stacked on top of one another from the directory
    
    path = full file path
    
    it also prints if the columns were of equal length
    """
    
    # pull each csv into a list
    dfs = []
    #insert path here
    #put in fullpath to file, and filetype = csv, txt, etc.
    path = "/home/rafa/github/For Businesses/Infinite-Agency/BG/*.csv" 
    count = 0
    for fname in glob.glob(path):
        count += 1
        print 'file number:{}'.format(count)
        dfs.append(pd.read_csv(fname))
    
    # creates a set of their column lengths
    shape_set = set([df.shape[1] for df in dfs])
    big_frame = pd.concat(dfs, ignore_index = True, axis = 0)
    
    if len(shape_set) > 1:
        print 'Unequal Columns!'
    else:
        print 'Columns are equal length :)\n Shape = {}'.format(big_frame.shape)
 
    big_frame.dropna(axis = 1, how = 'all', inplace=True)
    drop_nonunique(big_frame)
    return big_frame

# %%
def make_datelist(big_frame):
    datelist = []
    for column in big_frame.columns:
        if 'Date' in column:
            datelist.append(column)
    return datelist

# %%
def change_date(big_frame, datelist):
    datelist = []
    for column in datelist:
        big_frame[column] = pd.to_datetime(big_frame[column], infer_datetime_format=False)
    return big_frame

# %%
def drop_nonConversions(big_frame, datelist):
    for column in datelist:
        if column != 'ConversionDate':
            big_frame.drop(column, axis=1, inplace=True)

# %%
def drop_nonunique(big_frame):
    for column in big_frame.columns:
        if len(big_frame[column].unique()) == 1:
            big_frame.drop(column, axis=1, inplace=True)
    print big_frame.shape

# %% [markdown]
# # Create frame and add new columns
# -------------------------------

# %%
big_frame = make_big_frame()
big_frame.shape
datelist = make_datelist(big_frame)
drop_nonConversions(big_frame, datelist)
big_frame = change_date(big_frame, datelist)
big_frame = change_date(big_frame, datelist)
big_frame.drop_duplicates(inplace = True, subset = ['ConversionID'])
big_frame.reset_index(inplace=True)
big_frame.shape
# Out:
# file number:1
# file number:2
# file number:3
# file number:4
# file number:5
# Columns are equal length :)
#  Shape = (295, 4573)
# (295, 1057)
# (109, 969)

# %%
time_list = []
for datetimes in big_frame['ConversionDate']:
    time_list.append(int(datetimes[11:13]))

# %%
path_lst = []
for column in big_frame.columns:
    if 'PlacementName/SearchKeywordName' in column:
        path_lst.append(column)

# %%
paths_by_name = []
for row in range(big_frame.shape[0]):
    path_name = []
    for item in range(len(path_lst)):
        path_name.append(big_frame.loc[row, path_lst[item]])
    
    
    paths_by_name.append(path_name)
    
for index, path in enumerate(paths_by_name):
    paths_by_name[index] = [node for node in path if isinstance(node, str)]

# %%
path_lengths = [len(path) for path in paths_by_name]
big_frame['path_lengths'] = path_lengths
big_frame['paths_by_adname'] = paths_by_name
big_frame['hour'] = time_list

# %% [markdown]
# # Make new frames

# %%
state_list = big_frame['State-Region'].unique()
new_frame = big_frame[['ConversionID','BrowserType', 'OperatingSystemType', 'DeviceType','path_lengths', 'paths_by_adname', 'State-Region', 'hour']]
smaller_frames = []
for states in state_list:
    smaller_frames.append(new_frame[new_frame['State-Region'] == states])

# %%
after_hours = new_frame[(new_frame['hour'] < 10) | (new_frame['hour'] > 22)].sort_values(by = ['path_lengths'])
during_hours = new_frame[(new_frame['hour'] > 10) & (new_frame['hour'] < 22)].sort_values(by = ['path_lengths'])

# %% [markdown]
# # Plot time of day histograms

# %%
new_frame['hour'].count()
# Out:
# 109

# %%
fonts = 20
f, (ax0) = plt.subplots(1, 1, figsize = (10, 10))

ax0.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')
ax0.hist(new_frame['hour'], bins = 24, color = '#a7c059', zorder = 3, histtype='bar', ec='#383632')
ax0.set_title('Conversions by Time of Day \n Total Conversions = {}'.format(new_frame.shape[0]))
ax0.set_xlabel('Time of Day', fontsize = fonts)
ax0.set_ylabel('Conversions', fontsize = fonts)

# ax1.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')
# ax1.hist(after_hours['hour'], bins = 24, color = '#a7c059', zorder = 3)
# ax1.set_title('Between 10 pm and 10 am\nTotal Conversions = {}'.format(after_hours.shape[0]))
# ax1.set_xlabel('Time of Day', fontsize = fonts)
# ax1.set_ylabel('Conversions', fontsize = fonts)


# ax2.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')
# ax2.hist(during_hours['hour'], bins = 24, color = '#a7c059', zorder = 3)
# ax2.set_title('Between 10 pm and 10 am\n Total Conversions = {}'.format(during_hours.shape[0]))
# ax2.set_xlabel('Time of Day', fontsize = fonts)
# ax2.set_ylabel('Conversions', fontsize = fonts)

plt.tight_layout()
plt.show()

# %%
optimal = new_frame[new_frame['path_lengths'] < 6]
optimal = optimal.sort_values(by = 'path_lengths')

# %%
ad_list = []
for path_name in optimal['paths_by_adname']:
    for ad in path_name:
        if ad not in ad_list:
            ad_list.append(ad)

# %%
vals = [0] * len(ad_list)

# %%
ads = dict(zip(ad_list, vals))

# %%
for different_paths in optimal['paths_by_adname']:
    for ad in different_paths:
        ads[ad] += 1

# %%
ads = sorted(ads.items(), key = operator.itemgetter(1))[::-1]

# %%
xvalues = range(1, len(ads) + 1)
yvalues = [ad[1] for ad in ads]
names = [ad[0][12::] for ad in ads]

# %%
sums = []
for index in range(len(yvalues)):
    sums.append(sum(yvalues[0:index]))

# %%
disp_avg = sum([ad[1] for ad in ads])/float(len(ads))
disp_avg
# Out:
# 19.818181818181817

# %%
fig, ax = plt.subplots(figsize = (10, 10))
plt.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')


ax = plt.bar(xvalues, 
             yvalues,
             ec='#383632',
             color='#a7c059', 
             zorder = 3)

plt.axhline(y = disp_avg, 
            zorder = 3, 
            color = '#383632', 
            linestyle = 'dashed', 
            label = 'Avg Impressions')

plt.ylabel('Number of Impressions')
# plt.xlabel('Ad Type')

plt.xticks(xvalues, 
           names, 
           rotation = 90)


plt.legend()
plt.show()

# %%
big_frame['path_lengths'].mean()
# Out:
# 4.284403669724771

# %%
f, (ax0) = plt.subplots(1, 1, figsize = (10, 10))

ax0.grid(zorder = 0, linestyle = 'dashed', color = '#acaaa8')
ax0.hist(big_frame['path_lengths'], bins = 30, color = '#a7c059', zorder = 3, histtype='bar', ec='#383632')
ax0.set_title('Histogram \n Number of Paths')
ax0.set_xlabel('Path Length', fontsize = fonts)
ax0.set_ylabel('Number of People', fontsize = fonts)


plt.axhline(y = big_frame['path_lengths'].mean(), 
            zorder = 3, 
            color = '#383632', 
            linestyle = 'dashed', 
            label = 'Avg Path Length')

# %%
optimal.head()
# Out:
#      ConversionID  BrowserType OperatingSystemType   DeviceType  path_lengths  \
# 0    464635931143       Safari            iOS 10.3  Smart Phone             1
# 47   464371561371  Unsupported            iOS 10.2       Tablet             1
# 49   463103423728       Safari            iOS 10.2  Smart Phone             1
# 107  468396459169       Safari            iOS 10.3  Smart Phone             1
# 53   468102255088       Chrome    Mac 10.12 Sierra          Mac             1
#
#                               paths_by_adname   State-Region  hour
# 0      [Prospecting_FirstSteps_Mobile_320x50]     Washington    11
# 47     [Prospecting_FirstSteps_Mobile_320x50]      Wisconsin    16
# 49     [Prospecting_FirstSteps_Mobile_320x50]     Washington    16
# 107  [Prospecting_First Steps_OwnerIQ_728x90]  Massachusetts    23
# 53          [Prospecting_RICH_Flight_300x250]     Washington    23

# %%
optimal_list = []
for lengths in optimal['path_lengths'].unique():
    df = optimal[optimal['path_lengths'] == lengths]
    optimal_list.append(df)

# %%
optimal_list[4]
# Out:
#     ConversionID BrowserType OperatingSystemType   DeviceType  path_lengths  \
# 32  467320224071      Chrome          Windows XP           PC             5
# 31  464645835199      Chrome         Android 6.0  Smart Phone             5
# 2   464645835200      Chrome         Android 6.0  Smart Phone             5
# 28  467320224070      Chrome          Windows XP           PC             5
# 5   464645835201      Chrome         Android 6.0  Smart Phone             5
# 19  467320224072      Chrome          Windows XP           PC             5
# 33  464645835192      Chrome         Android 6.0  Smart Phone             5
# 37  464645835191      Chrome         Android 6.0  Smart Phone             5
# 80  464272581923      Safari            iOS 10.3  Smart Phone             5
# 76  464272581924      Safari            iOS 10.3  Smart Phone             5
# 71  464272581909      Safari            iOS 10.3  Smart Phone             5
# 70  464272581908      Safari            iOS 10.3  Smart Phone             5
# 22  467320224075      Chrome          Windows XP           PC             5
# 21  467320224074      Chrome          Windows XP           PC             5
# 20  467320224073      Chrome          Windows XP           PC             5
# 55  463956962179     Firefox           Windows 7           PC             5
# 95  467607388178      Safari            iOS 10.3  Smart Phone             5
# 26  464645835198      Chrome         Android 6.0  Smart Phone             5
#
#                                       paths_by_adname State-Region  hour
# 32  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    15
# 31  [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13
# 2   [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13
# 28  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    15
# 5   [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13
# 19  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    14
# 33  [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13
# 37  [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13
# 80  [Prospecting_Standard_PreRoll, Prospecting_You...   Washington     8
# 76  [Prospecting_Standard_PreRoll, Prospecting_You...   Washington     9
# 71  [Prospecting_Standard_PreRoll, Prospecting_You...   Washington     9
# 70  [Prospecting_Standard_PreRoll, Prospecting_You...   Washington     9
# 22  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    15
# 21  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    15
# 20  [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...        Texas    15
# 55  [Prospecting_First Steps_OwnerIQ_300x250, Pros...    Minnesota     6
# 95  [Prospecting_Flight_Mobile_320x50, Prospecting...    Minnesota    11
# 26  [Prospecting_Standard_PreRoll, Prospecting_Sta...   Washington    13

# %%
count_paths = Counter()
for paths in optimal['paths_by_adname']:
    count_paths[str(paths)] += 1
    
count_paths = sorted(count_paths.items(), key = operator.itemgetter(1))[::-1]

# %%
for item in count_paths:
    print item
# Out:
# ("['Prospecting_FirstSteps_Mobile_320x50']", 7)
# ("['Prospecting_YourTurn_OwnerIQ_728x90', 'Prospecting_YourTurn_OwnerIQ_728x90', 'Prospecting_First Steps_OwnerIQ_728x90', 'Prospecting_First Steps_OwnerIQ_300x250', 'Prospecting_YourTurn_OwnerIQ_300x250']", 6)
# ("['Prospecting_YourTurn_Mobile_320x50']", 6)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Standard_PreRoll', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 6)
# ("['Prospecting_Standard_PreRoll']", 5)
# ("['Prospecting_First Steps_OwnerIQ_300x250']", 5)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Flight_Mobile_320x50', 'Prospecting_Flight_Mobile_320x50']", 4)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_Standard_PreRoll', 'Prospecting_Standard_PreRoll', 'Prospecting_Standard_PreRoll']", 4)
# ("['Prospecting_Flight_Mobile_320x50', 'Prospecting_Flight_Mobile_320x50']", 3)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Flight_OwnerIQ_300x250']", 3)
# ("['Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 3)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_FirstSteps_Mobile_320x50']", 3)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Flight_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50']", 2)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Standard_PreRoll']", 2)
# ("['Prospecting_First Steps_OwnerIQ_728x90']", 2)
# ("['Prospecting_Flight_OwnerIQ_728x90']", 2)
# ("['Prospecting_YourTurn_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_Standard_PreRoll']", 2)
# ("['Prospecting_YourTurn_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50']", 2)
# ("['Prospecting_Flight_Mobile_320x50', 'Prospecting_Flight_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 2)
# ("['Prospecting_RICH_Flight_300x250', 'Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 2)
# ("['Prospecting_RICH_Flight_300x250']", 2)
# ("['Prospecting_Flight_OwnerIQ_300x250']", 2)
# ("['Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 1)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_Standard_PreRoll', 'Prospecting_Flight_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50']", 1)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_YourTurn_Mobile_320x50']", 1)
# ("['Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_Standard_PreRoll']", 1)
# ("['Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 1)
# ("['Prospecting_Flight_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_Standard_PreRoll', 'Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_FirstSteps_Mobile_320x50']", 1)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_RICH_Flight_300x250', 'Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 1)
# ("['Prospecting_Flight_OwnerIQ_300x250', 'Prospecting_Flight_OwnerIQ_300x250', 'Prospecting_YourTurn_OwnerIQ_300x250', 'Prospecting_Flight_OwnerIQ_300x250']", 1)
# ("['Prospecting_Standard_PreRoll', 'Prospecting_YourTurn_Mobile_320x50', 'Prospecting_YourTurn_Mobile_320x50']", 1)
# ("['Prospecting_First Steps_OwnerIQ_300x250', 'Prospecting_YourTurn_OwnerIQ_300x250', 'Prospecting_First Steps_OwnerIQ_300x250', 'Prospecting_YourTurn_OwnerIQ_300x250', 'Prospecting_Flight_OwnerIQ_300x250']", 1)
# ("['Prospecting_FirstSteps_Mobile_320x50', 'Prospecting_Flight_Mobile_320x50']", 1)

# %%
optimal
# Out:
#      ConversionID                        BrowserType OperatingSystemType  \
# 0    464635931143                             Safari            iOS 10.3
# 47   464371561371                        Unsupported            iOS 10.2
# 49   463103423728                             Safari            iOS 10.2
# 107  468396459169                             Safari            iOS 10.3
# 53   468102255088                             Chrome    Mac 10.12 Sierra
# 54   468102255089                             Chrome    Mac 10.12 Sierra
# 58   463109810082                             Safari            iOS 10.3
# 77   464371561373                        Unsupported            iOS 10.2
# 83   464232627908                             Chrome         Android 7.0
# 91   464492190188                             Safari             iOS 9.3
# 92   464479132870                             Safari            iOS 10.3
# 93   464118446968  Internet Explorer on Windows 7_8           Windows 10
# 94   464118446969  Internet Explorer on Windows 7_8           Windows 10
# 96   464118446965  Internet Explorer on Windows 7_8           Windows 10
# 97   464118446966  Internet Explorer on Windows 7_8           Windows 10
# 98   464118446967  Internet Explorer on Windows 7_8           Windows 10
# 105  468238697661                             Chrome          Windows 10
# 106  468238697662                             Chrome          Windows 10
# 46   462516061894                             Chrome         Android 5.0
# 44   464371561372                        Unsupported            iOS 10.2
# 108  468396459170                             Safari            iOS 10.3
# 17   467357311383                             Chrome         Android 7.0
# 18   467357311401                             Chrome         Android 7.0
# 15   467323092213                             Safari        Mac Yosemite
# 3    467359210744                               Edge          Windows 10
# 6    467465234569                             Chrome         Android 7.0
# 7    467465234570                             Chrome         Android 7.0
# 8    467359210742                               Edge          Windows 10
# 10   467359210743                               Edge          Windows 10
# 14   467323092212                             Safari        Mac Yosemite
# ..            ...                                ...                 ...
# 75   464378723975                        Unsupported             iOS 9.3
# 103  468166069292                             Chrome         Android 7.0
# 64   463436101617                             Safari            iOS 10.2
# 62   463436101618                             Safari            iOS 10.2
# 104  468166069291                             Chrome         Android 7.0
# 45   462905850479                             Chrome         Android 6.0
# 101  464378723978                        Unsupported             iOS 9.3
# 73   463240834192                            Firefox           Windows 7
# 69   463749541371                             Safari            iOS 10.3
# 41   467285367321                             Safari            iOS 10.3
# 39   467285367320                             Safari            iOS 10.3
# 89   467501170421                             Safari            iOS 10.2
# 32   467320224071                             Chrome          Windows XP
# 31   464645835199                             Chrome         Android 6.0
# 2    464645835200                             Chrome         Android 6.0
# 28   467320224070                             Chrome          Windows XP
# 5    464645835201                             Chrome         Android 6.0
# 19   467320224072                             Chrome          Windows XP
# 33   464645835192                             Chrome         Android 6.0
# 37   464645835191                             Chrome         Android 6.0
# 80   464272581923                             Safari            iOS 10.3
# 76   464272581924                             Safari            iOS 10.3
# 71   464272581909                             Safari            iOS 10.3
# 70   464272581908                             Safari            iOS 10.3
# 22   467320224075                             Chrome          Windows XP
# 21   467320224074                             Chrome          Windows XP
# 20   467320224073                             Chrome          Windows XP
# 55   463956962179                            Firefox           Windows 7
# 95   467607388178                             Safari            iOS 10.3
# 26   464645835198                             Chrome         Android 6.0
#
#       DeviceType  path_lengths  \
# 0    Smart Phone             1
# 47        Tablet             1
# 49   Smart Phone             1
# 107  Smart Phone             1
# 53           Mac             1
# 54           Mac             1
# 58   Smart Phone             1
# 77        Tablet             1
# 83   Smart Phone             1
# 91        Tablet             1
# 92   Smart Phone             1
# 93            PC             1
# 94            PC             1
# 96            PC             1
# 97            PC             1
# 98            PC             1
# 105           PC             1
# 106           PC             1
# 46   Smart Phone             1
# 44        Tablet             1
# 108  Smart Phone             1
# 17   Smart Phone             1
# 18   Smart Phone             1
# 15           Mac             1
# 3             PC             1
# 6    Smart Phone             1
# 7    Smart Phone             1
# 8             PC             1
# 10            PC             1
# 14           Mac             1
# ..           ...           ...
# 75        Tablet             3
# 103  Smart Phone             3
# 64   Smart Phone             3
# 62   Smart Phone             3
# 104  Smart Phone             3
# 45   Smart Phone             3
# 101       Tablet             3
# 73            PC             4
# 69   Smart Phone             4
# 41        Tablet             4
# 39        Tablet             4
# 89   Smart Phone             4
# 32            PC             5
# 31   Smart Phone             5
# 2    Smart Phone             5
# 28            PC             5
# 5    Smart Phone             5
# 19            PC             5
# 33   Smart Phone             5
# 37   Smart Phone             5
# 80   Smart Phone             5
# 76   Smart Phone             5
# 71   Smart Phone             5
# 70   Smart Phone             5
# 22            PC             5
# 21            PC             5
# 20            PC             5
# 55            PC             5
# 95   Smart Phone             5
# 26   Smart Phone             5
#
#                                        paths_by_adname   State-Region  hour
# 0               [Prospecting_FirstSteps_Mobile_320x50]     Washington    11
# 47              [Prospecting_FirstSteps_Mobile_320x50]      Wisconsin    16
# 49              [Prospecting_FirstSteps_Mobile_320x50]     Washington    16
# 107           [Prospecting_First Steps_OwnerIQ_728x90]  Massachusetts    23
# 53                   [Prospecting_RICH_Flight_300x250]     Washington    23
# 54                   [Prospecting_RICH_Flight_300x250]     Washington    23
# 58                      [Prospecting_Standard_PreRoll]     Washington    13
# 77              [Prospecting_FirstSteps_Mobile_320x50]      Wisconsin    16
# 83                [Prospecting_YourTurn_Mobile_320x50]      Minnesota    23
# 91              [Prospecting_FirstSteps_Mobile_320x50]       Illinois    20
# 92              [Prospecting_FirstSteps_Mobile_320x50]     Washington    22
# 93           [Prospecting_First Steps_OwnerIQ_300x250]     Washington    16
# 94           [Prospecting_First Steps_OwnerIQ_300x250]     Washington    16
# 96           [Prospecting_First Steps_OwnerIQ_300x250]     Washington    12
# 97           [Prospecting_First Steps_OwnerIQ_300x250]     Washington    12
# 98           [Prospecting_First Steps_OwnerIQ_300x250]     Washington    13
# 105               [Prospecting_Flight_OwnerIQ_300x250]     Washington    17
# 106               [Prospecting_Flight_OwnerIQ_300x250]     Washington    17
# 46                      [Prospecting_Standard_PreRoll]        Florida    14
# 44              [Prospecting_FirstSteps_Mobile_320x50]      Wisconsin    16
# 108           [Prospecting_First Steps_OwnerIQ_728x90]  Massachusetts    23
# 17                [Prospecting_YourTurn_Mobile_320x50]  Massachusetts    12
# 18                [Prospecting_YourTurn_Mobile_320x50]  Massachusetts    12
# 15                 [Prospecting_Flight_OwnerIQ_728x90]       Michigan    13
# 3                       [Prospecting_Standard_PreRoll]     Washington    16
# 6                 [Prospecting_YourTurn_Mobile_320x50]      Minnesota    19
# 7                 [Prospecting_YourTurn_Mobile_320x50]      Minnesota    19
# 8                       [Prospecting_Standard_PreRoll]     Washington    16
# 10                      [Prospecting_Standard_PreRoll]     Washington    16
# 14                 [Prospecting_Flight_OwnerIQ_728x90]       Michigan    13
# ..                                                 ...            ...   ...
# 75   [Prospecting_Standard_PreRoll, Prospecting_Fli...      Minnesota    13
# 103  [Prospecting_Flight_Mobile_320x50, Prospecting...     California     0
# 64   [Prospecting_YourTurn_Mobile_320x50, Prospecti...     Washington    14
# 62   [Prospecting_YourTurn_Mobile_320x50, Prospecti...     Washington    14
# 104  [Prospecting_Flight_Mobile_320x50, Prospecting...     California     0
# 45   [Prospecting_YourTurn_Mobile_320x50, Prospecti...     Washington    19
# 101  [Prospecting_Standard_PreRoll, Prospecting_Fli...      Minnesota    14
# 73   [Prospecting_Flight_OwnerIQ_300x250, Prospecti...      Minnesota    20
# 69   [Prospecting_Standard_PreRoll, Prospecting_Sta...      Minnesota    14
# 41   [Prospecting_Standard_PreRoll, Prospecting_Fli...      Minnesota    16
# 39   [Prospecting_Standard_PreRoll, Prospecting_Fli...      Minnesota    16
# 89   [Prospecting_Standard_PreRoll, Prospecting_RIC...     Washington     9
# 32   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    15
# 31   [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
# 2    [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
# 28   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    15
# 5    [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
# 19   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    14
# 33   [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
# 37   [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
# 80   [Prospecting_Standard_PreRoll, Prospecting_You...     Washington     8
# 76   [Prospecting_Standard_PreRoll, Prospecting_You...     Washington     9
# 71   [Prospecting_Standard_PreRoll, Prospecting_You...     Washington     9
# 70   [Prospecting_Standard_PreRoll, Prospecting_You...     Washington     9
# 22   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    15
# 21   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    15
# 20   [Prospecting_YourTurn_OwnerIQ_728x90, Prospect...          Texas    15
# 55   [Prospecting_First Steps_OwnerIQ_300x250, Pros...      Minnesota     6
# 95   [Prospecting_Flight_Mobile_320x50, Prospecting...      Minnesota    11
# 26   [Prospecting_Standard_PreRoll, Prospecting_Sta...     Washington    13
#
# [86 rows x 8 columns]
